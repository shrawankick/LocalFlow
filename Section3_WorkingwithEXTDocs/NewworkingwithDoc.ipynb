# %%
# %pip install unstructured pdfminer.six
# %pip install --upgrade unstructured
# Out:
# Collecting unstructured
#   Using cached unstructured-0.18.21-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pdfminer.six in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (20251107)
# Requirement already satisfied: charset-normalizer in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (3.4.4)
# Requirement already satisfied: filetype in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (6.0.2)
# Requirement already satisfied: nltk in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (3.9.2)
# Requirement already satisfied: requests in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (4.14.3)
# Requirement already satisfied: emoji in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (2.15.0)
# Requirement already satisfied: dataclasses-json in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (2025.11.16)
# Requirement already satisfied: langdetect in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (1.0.9)
# Collecting numpy (from unstructured)
#   Using cached numpy-2.3.5-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: rapidfuzz in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (3.14.3)
# Requirement already satisfied: backoff in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (4.15.0)
# Collecting unstructured-client (from unstructured)
#   Using cached unstructured_client-0.42.4-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (2.0.1)
# Requirement already satisfied: tqdm in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in c:\users\shraw\appdata\roaming\python\python314\site-packages (from unstructured) (7.1.3)
# Requirement already satisfied: python-oxmsg in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pdfminer.six) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from beautifulsoup4->unstructured) (2.8)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\shraw\appdata\roaming\python\python314\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (25.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: six>=1.9 in c:\users\shraw\appdata\roaming\python\python314\site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from nltk->unstructured) (8.3.1)
# Requirement already satisfied: joblib in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from nltk->unstructured) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from nltk->unstructured) (2025.11.3)
# Requirement already satisfied: colorama in c:\users\shraw\appdata\roaming\python\python314\site-packages (from click->nltk->unstructured) (0.4.6)
# Requirement already satisfied: olefile in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->unstructured) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->unstructured) (2025.11.12)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (25.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (2.12.5)
# Requirement already satisfied: pypdf>=6.2.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (6.4.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: h11>=0.16 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.12.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.2)
# Using cached unstructured-0.18.21-py3-none-any.whl (1.8 MB)
# Using cached numpy-2.3.5-cp314-cp314-win_amd64.whl (12.9 MB)
# Using cached unstructured_client-0.42.4-py3-none-any.whl (207 kB)
# Installing collected packages: numpy, unstructured-client, unstructured
#
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ------------- -------------------------- 1/3 [unstructured-client]
#    ------------- -------------------------- 1/3 [unstructured-client]
#    ------------- -------------------------- 1/3 [unstructured-client]
#    -------------------------- ------------- 2/3 [unstructured]
#    -------------------------- ------------- 2/3 [unstructured]
#    -------------------------- ------------- 2/3 [unstructured]
#    -------------------------- ------------- 2/3 [unstructured]
#    -------------------------- ------------- 2/3 [unstructured]
#    ---------------------------------------- 3/3 [unstructured]
#
# Successfully installed numpy-2.3.5 unstructured-0.18.21 unstructured-client-0.42.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\shraw\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Requirement already satisfied: unstructured in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.18.21)
# Requirement already satisfied: charset-normalizer in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (3.4.4)
# Requirement already satisfied: filetype in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (6.0.2)
# Requirement already satisfied: nltk in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (3.9.2)
# Requirement already satisfied: requests in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (4.14.3)
# Requirement already satisfied: emoji in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (2.15.0)
# Requirement already satisfied: dataclasses-json in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (2025.11.16)
# Requirement already satisfied: langdetect in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (2.3.5)
# Requirement already satisfied: rapidfuzz in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (3.14.3)
# Requirement already satisfied: backoff in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (4.15.0)
# Requirement already satisfied: unstructured-client in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (0.42.4)
# Requirement already satisfied: wrapt in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (2.0.1)
# Requirement already satisfied: tqdm in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in c:\users\shraw\appdata\roaming\python\python314\site-packages (from unstructured) (7.1.3)
# Requirement already satisfied: python-oxmsg in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from beautifulsoup4->unstructured) (2.8)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\shraw\appdata\roaming\python\python314\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (25.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: six>=1.9 in c:\users\shraw\appdata\roaming\python\python314\site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from nltk->unstructured) (8.3.1)
# Requirement already satisfied: joblib in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from nltk->unstructured) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from nltk->unstructured) (2025.11.3)
# Requirement already satisfied: colorama in c:\users\shraw\appdata\roaming\python\python314\site-packages (from click->nltk->unstructured) (0.4.6)
# Requirement already satisfied: olefile in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->unstructured) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->unstructured) (2025.11.12)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (25.1.0)
# Requirement already satisfied: cryptography>=3.1 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (46.0.3)
# Requirement already satisfied: httpcore>=1.0.9 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (2.12.5)
# Requirement already satisfied: pypdf>=6.2.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (6.4.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from cffi>=2.0.0->cryptography>=3.1->unstructured-client->unstructured) (2.23)
# Requirement already satisfied: h11>=0.16 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.12.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\shraw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_community.document_loaders import UnstructuredPDFLoader

# 1. Create the empty list to store all document chunks
documents = []

# 2. Define the directory where your PDFs are stored
# Replace './your_pdf_folder' with the actual path to your folder
directory = './Docs'

# 3. Loop through files in the directory
for filename in os.listdir(directory):
    
    # Check if the file is actually a PDF
    if filename.endswith('.pdf'):
        
        # 4. Construct the full file path (os.path.join)
        # The transcript emphasized this was crucial to avoid errors
        file_path = os.path.join(directory, filename)
        
        # 5. Create the loader with the file path
        loader = UnstructuredPDFLoader(file_path)
        
        # 6. Load the file and append (extend) it to the main documents list
        documents.extend(loader.load())

# Verify the data was loaded
print(f"Successfully loaded {len(documents)} documents.")
# Out:
# c:\Users\shraw\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 12
#       9 directory = './Docs'
#      11 # 3. Loop through files in the directory
# ---> 12 for filename in os.listdir(directory):
#      13
#      14     # Check if the file is actually a PDF
#      15     if filename.endswith('.pdf'):
#      16
#      17         # 4. Construct the full file path (os.path.join)
#      18         # The transcript emphasized this was crucial to avoid errors
#      19         file_path = os.path.join(directory, filename)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: './Docs'
