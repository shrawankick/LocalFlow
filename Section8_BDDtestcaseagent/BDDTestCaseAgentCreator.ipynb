# %%
from langchain_ollama import ChatOllama

llm_tc = ChatOllama(
    base_url="http://localhost:11434",
    model="gpt-oss:20b-cloud",
    temperature=0.5
)

llm = ChatOllama(
    base_url="http://localhost:11434",
    model="ministral-3:8b-cloud",
    temperature=0.5
)

# %%
from langchain.tools import tool 
from langchain_core.prompts import PromptTemplate

@tool
def generate_TestCase(user_story: str) -> str:
    """Generate a test case based on the given user story."""
    prompt_template = PromptTemplate.from_template(
        """
        You are a software testing expert. 
        Given the following user story, generate a detailed test case that includes the test title, description, preconditions, steps to execute, expected results, and postconditions.
        include the combinations of valid invalid edge cases and alternative flow scenarios 
                
        user story:{user_story}
        Format the test case in a clear and structured manner.
        Format:
        Test Case Title: <Title>
        Description: <Description>
        Preconditions: <Preconditions>
        Steps to Execute:
        1. <Step 1>
        2. <Step 2>
        ...Expected Results:
        1. <Expected Result 1>
        2. <Expected Result 2>
        ...Postconditions: <Postconditions> 
        and ensure clarity and completeness.  

         no gerkin syntax
        """
    )
    #prompt = prompt_template.invoke(user_story=user_story)
    prompt = prompt_template.invoke({"user_story": user_story})
    return llm_tc.invoke(prompt)
    #response = llm.generate([prompt.format(user_story=user_story)])
    #return response.generations[0][0].text.strip()

# %%
import os
from langchain.agents import create_agent
agent = create_agent(
    model=llm,
    tools=[generate_TestCase]
)

UserStory_input = """As a user, I want to be able to reset my password so that I can regain access to my account if I forget my current password."""

#result = agent.invoke(f"Generate a BDD test case for the following user story: {UserStory_input}")
#print(result)
# 2. Invoke with a dictionary containing "messages"
result = agent.invoke({
    "messages": [("user", f"Generate a  test case for the following user story: {UserStory_input}")]
})

# 3. Print the output (usually found in the last message)
print(result["messages"][-1].content)
# Out:
# Here are the test cases for the user story **"As a user, I want to be able to reset my password so that I can regain access to my account if I forget my current password."**:
#
# ---
#
# ### **Test Case 1 – Valid Password Reset Flow**
# **Description:** Verify that a registered user can successfully reset their password using the standard workflow.
#
# **Preconditions:**
# - User has an active account with email **user@example.com**.
# - User is logged out of the application.
# - Password reset email functionality is operational.
#
# **Steps to Execute:**
# 1. Navigate to the *Login* page.
# 2. Click the *Forgot Password* link.
# 3. Enter **user@example.com** in the email field and submit.
# 4. Check the inbox for the password-reset email.
# 5. Click the reset link in the email.
# 6. On the reset page, enter a new password that meets complexity rules (e.g., `NewP@ssw0rd!`).
# 7. Re-enter the new password in the confirmation field.
# 8. Submit the form.
#
# **Expected Results:**
# 1. The *Forgot Password* page confirms that an email has been sent.
# 2. The email arrives within a reasonable time (≤ 2 minutes).
# 3. The reset link opens the *Reset Password* page.
# 4. Entering matching passwords that satisfy complexity displays a success message.
# 5. The user is redirected to the *Login* page with a message: *“Password successfully reset. Please log in.”*
# 6. Logging in with the new password succeeds.
#
# **Postconditions:**
# - The user’s password is updated.
# - The reset token is invalidated.
#
# ---
#
# ### **Test Case 2 – Unregistered Email Address**
# **Description:** Ensure the system does not reveal whether an email is registered and handles the request gracefully.
#
# **Preconditions:**
# - User is logged out.
#
# **Steps to Execute:**
# 1. Navigate to the *Login* page.
# 2. Click *Forgot Password*.
# 3. Enter **unknown@example.com** (not in the system) in the email field.
# 4. Submit the form.
#
# **Expected Results:**
# 1. The system displays a generic confirmation: *“If this email is registered, a reset link has been sent.”*
# 2. No email is sent.
#
# **Postconditions:**
# - No new reset token is created.
#
# ---
#
# ### **Test Case 3 – Invalid Email Format**
# **Description:** Validate that the system rejects improperly formatted email addresses.
#
# **Preconditions:**
# - User is logged out.
#
# **Steps to Execute:**
# 1. Navigate to the *Login* page.
# 2. Click *Forgot Password*.
# 3. Enter **invalid-email** (no @ or domain) in the email field.
# 4. Submit the form.
#
# **Expected Results:**
# 1. The form shows a validation error: *“Please enter a valid email address.”*
# 2. No reset email is sent.
#
# **Postconditions:**
# - No reset token is generated.
#
# ---
#
# ### **Test Case 4 – Expired Reset Token**
# **Description:** Confirm that a reset link that has expired is rejected.
#
# **Preconditions:**
# - A password reset email has been sent to **user@example.com**.
# - The token’s validity period (e.g., 1 hour) has elapsed.
#
# **Steps to Execute:**
# 1. Click the expired reset link in the email.
# 2. The *Reset Password* page loads.
# 3. Enter a new password and confirmation.
# 4. Submit the form.
#
# **Expected Results:**
# 1. The page displays an error: *“Reset link has expired. Please request a new password reset.”*
# 2. The password is not changed.
#
# **Postconditions:**
# - The expired token remains invalid.
#
# ---
#
# ### **Test Case 5 – Re-use of Reset Token**
# **Description:** Verify that a reset token cannot be used a second time.
#
# **Preconditions:**
# - User has successfully reset their password using a token.
#
# **Steps to Execute:**
# 1. Attempt to click the same reset link again.
# 2. Enter a new password.
# 3. Submit the form.
#
# **Expected Results:**
# 1. The system displays: *“Reset link has already been used.”*
# 2. No further password change occurs.
#
# **Postconditions:**
# - Token remains invalid.
#
# ---
#
# ### **Test Case 6 – Password Complexity & Edge Cases**
# **Description:** Test various password inputs that violate complexity rules or are edge cases.
#
# **Preconditions:**
# - User has a valid reset link.
#
# **Steps to Execute:**
# 1. On the *Reset Password* page, enter the following passwords in separate iterations:
#    - a) `short` (too short)
#    - b) `alllowercasepassword` (no uppercase, no digits, no special chars)
#    - c) `ALLUPPERCASE123!` (no lowercase)
#    - d) `PasswordWithNoSpecial123` (no special char)
#    - e) `ValidP@ssw0rd!` (meets all rules)
# 2. For each iteration, re-enter the same password in the confirmation field and submit.
#
# **Expected Results:**
# 1. For a–d, the form shows specific validation messages (e.g., *“Password must be at least 8 characters”*, *“Password must contain an uppercase letter”*, etc.).
# 2. For e, the password is accepted, and the user is redirected to the *Login* page.
#
# **Postconditions:**
# - Only the valid password change is persisted.
#
# ---
# These test cases ensure comprehensive coverage of the password reset functionality, including success scenarios, edge cases, and error handling.

# %% [markdown]
# Other optional items are
#
#   title
#         preconditions
#         Action steps
#         expected results
#         clean up steps

# %% [markdown]
# result = agent.invoke({
#     "messages": [("user", f"Generate a  BDD test case for the following user story: {UserStory_input}")]
# })
