# %% [markdown]
# ### Working with Playwright

# %% [markdown]
# So when you are installing the Playwright in the new machine, you might get this error. At the end you might get the error that the browser is not available or something like that. So when you are doing that what you need to do
# ince you see .venv in your PowerShell prompt (e.g., (.venv) PS C:\Users\YourName\YourProject>), you are already inside your virtual environment. You do not need to go anywhere else.
#
# Here are the specific instructions to fix your installation right now.
#
# Step 1: Run these two commands
# Type these commands into your PowerShell terminal one by one, pressing Enter after each line.
#
# Command 1: Install the Python Library This downloads the Playwright code so Python can talk to browsers.
#
# PowerShell
#
# `pip install playwright`
# Command 2: Install the Browser Engines This is the step most people forget. It downloads the actual browser binaries (Chromium, Firefox, WebKit) that the code will control.
#
# PowerShell
#
# `playwright install`
# (Note: This second command might take a minute or two as it downloads about 100-200MB of browser files.)
#
# Step 2: Restart Your Kernel
# After the installation finishes in PowerShell, go back to your code editor (VS Code/Jupyter):
#
# Look at the top right of your notebook.
#
# Click the Restart button (usually a circular arrow icon ↻).
#
# This forces your notebook to "reload" and see the new libraries you just installed.
#
# Step 3: Verify with this Simple Test
# Once you have restarted, run this code in a new cell. If it prints the success message, you are 100% ready to go.
#
# Python
# `
# from playwright.async_api import async_playwright
#
# print("Playwright module is successfully installed!")`
# Why did you need to do this?
# Think of it like buying a remote control car:
#
# pip install playwright is buying the Remote Control (the Python code).
#
# playwright install is buying the Car itself (the Chromium browser).
#
# You need both to make it drive!

# %%
# %pip install langchain
# %pip install langchain-ollama 
# %pip install playwright 
# %pip install nest_asyncio
# %pip install lxml
# If this is your first time using playwright, you'll have to install a browser executable.
# Running `playwright install` by default installs a chromium browser executable.
# playwright install
# Out:
# Requirement already satisfied: langchain in e:\localflow\.venv\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in e:\localflow\.venv\lib\site-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in e:\localflow\.venv\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\localflow\.venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.4.53)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\localflow\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in e:\localflow\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in e:\localflow\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in e:\localflow\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.12)
# Requirement already satisfied: xxhash>=3.5.0 in e:\localflow\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in e:\localflow\.venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in e:\localflow\.venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in e:\localflow\.venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\localflow\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in e:\localflow\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.32.5)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\localflow\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.12.0)
# Requirement already satisfied: zstandard>=0.23.0 in e:\localflow\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in e:\localflow\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.12.0)
# Requirement already satisfied: certifi in e:\localflow\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in e:\localflow\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in e:\localflow\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in e:\localflow\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\localflow\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\localflow\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\localflow\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\localflow\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\localflow\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-ollama in e:\localflow\.venv\lib\site-packages (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in e:\localflow\.venv\lib\site-packages (from langchain-ollama) (1.1.0)
# Requirement already satisfied: ollama<1.0.0,>=0.6.0 in e:\localflow\.venv\lib\site-packages (from langchain-ollama) (0.6.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.4.53)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in e:\localflow\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\localflow\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\localflow\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in e:\localflow\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\localflow\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in e:\localflow\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.32.5)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\localflow\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.12.0)
# Requirement already satisfied: zstandard>=0.23.0 in e:\localflow\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.25.0)
# Requirement already satisfied: anyio in e:\localflow\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.12.0)
# Requirement already satisfied: certifi in e:\localflow\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in e:\localflow\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in e:\localflow\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in e:\localflow\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\localflow\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\localflow\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\localflow\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\localflow\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\localflow\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: playwright in e:\localflow\.venv\lib\site-packages (1.56.0)
# Requirement already satisfied: pyee<14,>=13 in e:\localflow\.venv\lib\site-packages (from playwright) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in e:\localflow\.venv\lib\site-packages (from playwright) (3.2.4)
# Requirement already satisfied: typing-extensions in e:\localflow\.venv\lib\site-packages (from pyee<14,>=13->playwright) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nest_asyncio in e:\localflow\.venv\lib\site-packages (1.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lxml in e:\localflow\.venv\lib\site-packages (6.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    base_url="http://localhost:11434",
    model="llama3.2:1b",
    temperature=0
)

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import (
    create_async_playwright_browser   
)
# from langchain_ollama import ChatOllama # <--- This is the key change
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### Get all tools from PlaywrightToolkit

# %%
import asyncio
print(type(asyncio.get_event_loop()))
# If this prints <class 'asyncio.windows_events.SelectorEventLoop'>, 
# Playwright will NEVER work in this specific notebook session.
# Out:
# <class 'asyncio.windows_events._WindowsSelectorEventLoop'>

# %%
# ---- 0️⃣ Notebook pre‑amble ----
import sys, nest_asyncio, asyncio
nest_asyncio.apply()

# On Windows force the selector loop – it supports subprocesses
if sys.platform.startswith("win"):
    asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())

from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import (
    create_async_playwright_browser   
)
async_browser = await create_async_playwright_browser(headless=False)

toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()
tools
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-30' coro=<Connection.run() done, defined at e:\LocalFlow\.venv\Lib\site-packages\playwright\_impl\_connection.py:305> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "C:\Users\shraw\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\tasks.py", line 304, in __step_run_and_handle_result
#     result = coro.send(None)
#   File "e:\LocalFlow\.venv\Lib\site-packages\playwright\_impl\_connection.py", line 312, in run
#     await self._transport.connect()
#   File "e:\LocalFlow\.venv\Lib\site-packages\playwright\_impl\_transport.py", line 133, in connect
#     raise exc
#   File "e:\LocalFlow\.venv\Lib\site-packages\playwright\_impl\_transport.py", line 120, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<9 lines>...
#     )
#     ^
#   File "C:\Users\shraw\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
#         stderr=stderr, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shraw\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\base_events.py", line 1802, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         protocol, popen_args, False, stdin, stdout, stderr,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         bufsize, **kwargs)
#         ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shraw\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\base_events.py", line 539, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[10], line 13
#       9 from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
#      10 from langchain_community.tools.playwright.utils import (
#      11     create_async_playwright_browser
#      12 )
# ---> 13 async_browser = await create_async_playwright_browser(headless=False)
#      14 toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
#      15 tools = toolkit.get_tools()
#
# File e:\LocalFlow\.venv\Lib\site-packages\langchain_community\tools\playwright\utils.py:69, in create_async_playwright_browser(headless, args)
#      57 """
#      58 Create an async playwright browser.
#      59
#    (...)     65     AsyncBrowser: The playwright browser.
#      66 """
#      67 from playwright.async_api import async_playwright
# ---> 69 browser = run_async(async_playwright().start())
#      70 return run_async(browser.chromium.launch(headless=headless, args=args))
#
# File e:\LocalFlow\.venv\Lib\site-packages\langchain_community\tools\playwright\utils.py:105, in run_async(coro)
#      96 """Run an async coroutine.
#      97
#      98 Args:
#    (...)    102     T: The result of the coroutine.
#     103 """
#     104 event_loop = asyncio.get_event_loop()
# --> 105 return event_loop.run_until_complete(coro)
#
# File e:\LocalFlow\.venv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File e:\LocalFlow\.venv\Lib\site-packages\playwright\async_api\_context_manager.py:51, in PlaywrightContextManager.start(self)
#      50 async def start(self) -> AsyncPlaywright:
# ---> 51     return await self.__aenter__()
#
# File e:\LocalFlow\.venv\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
#      48 return playwright
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File e:\LocalFlow\.venv\Lib\site-packages\playwright\_impl\_transport.py:120, in PipeTransport.connect(self)
#     117         startupinfo.wShowWindow = subprocess.SW_HIDE
#     119     executable_path, entrypoint_path = compute_driver_executable()
# --> 120     self._proc = await asyncio.create_subprocess_exec(
#     121         executable_path,
#     122         entrypoint_path,
#     123         "run-driver",
#     124         stdin=asyncio.subprocess.PIPE,
#     125         stdout=asyncio.subprocess.PIPE,
#     126         stderr=_get_stderr_fileno(),
#     127         limit=32768,
#     128         env=env,
#     129         startupinfo=startupinfo,
#     130     )
#     131 except Exception as exc:
#     132     self.on_error_future.set_exception(exc)
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\base_events.py:1802, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1800     debug_log = f'execute program {program!r}'
#    1801     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1802 transport = await self._make_subprocess_transport(
#    1803     protocol, popen_args, False, stdin, stdout, stderr,
#    1804     bufsize, **kwargs)
#    1805 if self._debug and debug_log is not None:
#    1806     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\base_events.py:539, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     535 async def _make_subprocess_transport(self, protocol, args, shell,
#     536                                      stdin, stdout, stderr, bufsize,
#     537                                      extra=None, **kwargs):
#     538     """Create subprocess transport."""
# --> 539     raise NotImplementedError
#
# NotImplementedError:

# %%
import sys, asyncio, nest_asyncio
nest_asyncio.apply()
if sys.platform.startswith("win"):
    asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

# %%
async_browser = await create_async_playwright_browser(headless=False)
print("✅ Browser launched →", async_browser)
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-81' coro=<Connection.run() done, defined at e:\LocalFlow\.venv\Lib\site-packages\playwright\_impl\_connection.py:305> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "C:\Users\shraw\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\tasks.py", line 304, in __step_run_and_handle_result
#     result = coro.send(None)
#   File "e:\LocalFlow\.venv\Lib\site-packages\playwright\_impl\_connection.py", line 312, in run
#     await self._transport.connect()
#   File "e:\LocalFlow\.venv\Lib\site-packages\playwright\_impl\_transport.py", line 133, in connect
#     raise exc
#   File "e:\LocalFlow\.venv\Lib\site-packages\playwright\_impl\_transport.py", line 120, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<9 lines>...
#     )
#     ^
#   File "C:\Users\shraw\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
#         stderr=stderr, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shraw\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\base_events.py", line 1802, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         protocol, popen_args, False, stdin, stdout, stderr,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         bufsize, **kwargs)
#         ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shraw\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\base_events.py", line 539, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 async_browser = await create_async_playwright_browser(headless=False)
#       2 print("✅ Browser launched →", async_browser)
#
# File e:\LocalFlow\.venv\Lib\site-packages\langchain_community\tools\playwright\utils.py:69, in create_async_playwright_browser(headless, args)
#      57 """
#      58 Create an async playwright browser.
#      59
#    (...)     65     AsyncBrowser: The playwright browser.
#      66 """
#      67 from playwright.async_api import async_playwright
# ---> 69 browser = run_async(async_playwright().start())
#      70 return run_async(browser.chromium.launch(headless=headless, args=args))
#
# File e:\LocalFlow\.venv\Lib\site-packages\langchain_community\tools\playwright\utils.py:105, in run_async(coro)
#      96 """Run an async coroutine.
#      97
#      98 Args:
#    (...)    102     T: The result of the coroutine.
#     103 """
#     104 event_loop = asyncio.get_event_loop()
# --> 105 return event_loop.run_until_complete(coro)
#
# File e:\LocalFlow\.venv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File e:\LocalFlow\.venv\Lib\site-packages\playwright\async_api\_context_manager.py:51, in PlaywrightContextManager.start(self)
#      50 async def start(self) -> AsyncPlaywright:
# ---> 51     return await self.__aenter__()
#
# File e:\LocalFlow\.venv\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
#      48 return playwright
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File e:\LocalFlow\.venv\Lib\site-packages\playwright\_impl\_transport.py:120, in PipeTransport.connect(self)
#     117         startupinfo.wShowWindow = subprocess.SW_HIDE
#     119     executable_path, entrypoint_path = compute_driver_executable()
# --> 120     self._proc = await asyncio.create_subprocess_exec(
#     121         executable_path,
#     122         entrypoint_path,
#     123         "run-driver",
#     124         stdin=asyncio.subprocess.PIPE,
#     125         stdout=asyncio.subprocess.PIPE,
#     126         stderr=_get_stderr_fileno(),
#     127         limit=32768,
#     128         env=env,
#     129         startupinfo=startupinfo,
#     130     )
#     131 except Exception as exc:
#     132     self.on_error_future.set_exception(exc)
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\base_events.py:1802, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1800     debug_log = f'execute program {program!r}'
#    1801     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1802 transport = await self._make_subprocess_transport(
#    1803     protocol, popen_args, False, stdin, stdout, stderr,
#    1804     bufsize, **kwargs)
#    1805 if self._debug and debug_log is not None:
#    1806     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\asyncio\base_events.py:539, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     535 async def _make_subprocess_transport(self, protocol, args, shell,
#     536                                      stdin, stdout, stderr, bufsize,
#     537                                      extra=None, **kwargs):
#     538     """Create subprocess transport."""
# --> 539     raise NotImplementedError
#
# NotImplementedError:

# %%
# ----------------------------------------------------
# 0️⃣  Diagnostic – which Python interpreter are we using?
# ----------------------------------------------------
import sys, asyncio, os, subprocess, shutil

print("🐍  Python executable :", sys.executable)
print("🗓️  Python version    :", sys.version.replace("\n", " "))
print("🔀  Event‑loop policy :", type(asyncio.get_event_loop_policy()).__name__)

# Is the Playwright driver on the PATH?
driver = shutil.which("playwright")
print("🔧  playwright CLI   :", driver or "not found")

# Try to run the Playwright driver directly (should print version)
if driver:
    try:
        out = subprocess.check_output([driver, "--version"], text=True)
        print("⚙️  playwright driver version :", out.strip())
    except Exception as e:
        print("⚠️  failed to run playwright driver:", e)
else:
    print("⚠️  Playwright CLI not installed (run `python -m playwright install`)")
# Out:
# 🐍  Python executable : e:\LocalFlow\.venv\Scripts\python.exe
# 🗓️  Python version    : 3.13.10 (tags/v3.13.10:4fd8843, Dec  2 2025, 15:08:18) [MSC v.1944 64 bit (AMD64)]
# 🔀  Event‑loop policy : WindowsSelectorEventLoopPolicy
# 🔧  playwright CLI   : e:\LocalFlow\.venv\Scripts\playwright.EXE
# ⚙️  playwright driver version : Version 1.56.0
