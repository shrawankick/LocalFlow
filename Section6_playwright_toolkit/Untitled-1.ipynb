# %% [markdown]
# C:\Windows\System32>wsl -d Ubuntu
# user@Shrawan:/mnt/c/Windows/System32$ cd.. E:\LocalFlow
# cd..: command not found
# user@Shrawan:/mnt/c/Windows/System32$ cd ~
# user@Shrawan:~$ cd /mnt/e/LocalFlow
# user@Shrawan:/mnt/e/LocalFlow$ code .

# %%
# %pip install langchain
# %pip install langchain-ollama 
# %pip install langchain_community
# %pip install playwright 
# %pip install asyncio
# %pip install nest_asyncio
# %pip install lxml

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    base_url="http://localhost:11434",
    model="gpt-oss:120b-cloud",
    temperature=0
)

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import (
    create_async_playwright_browser 
    ,create_sync_playwright_browser  
)
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
print(type(asyncio.get_event_loop()))
# If this prints <class 'asyncio.windows_events.SelectorEventLoop'>, 
# Playwright will NEVER work in this specific notebook session.

# %%
async_browser = create_async_playwright_browser()
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()
tools
